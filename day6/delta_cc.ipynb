# %%
delta internals

# %%
# %sql
use catalog lakehouse;

# %%
# %sql
create schema lakehouse.cc

# %%
# %sql
create schema lakehouse.cc managed location 'abfss://raw@adlsnaval123.dfs.core.windows.net/lakehouse/cc'

# %%
# %sql
create table lakehouse.cc.demo (id int, name string)

# %%
# %sql
select * from lakehouse.cc.demo

# %%
# %sql desc extended lakehouse.cc.demo

# %%
# %sql
insert into lakehouse.cc.demo values(2,'krishna'),(3,'Ram');

# %%
# %sql
select * from lakehouse.cc.demo;

# %%
# %sql
Insert into lakehouse.cc.demo values (4,'Dayanada');
Insert into lakehouse.cc.demo values (5,'Eswar');
Insert into lakehouse.cc.demo values (6,'Sangram');

# %%
# %sql
delete from lakehouse.cc.demo where id=2

# %%
# %sql
optimize lakehouse.cc.demo
zorder by id

# %%
# %sql
vacuum lakehouse.cc.demo

# %%
# %sql
rename schema lakehouse.cc to lakehouse.chetan
